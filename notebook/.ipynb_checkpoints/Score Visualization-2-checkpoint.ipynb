# %% [markdown]
# # Date: 2019-04-30 to 2019-05-13

# %%
import os
import gc
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.gridspec as gridspec
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
filename = '/home/phongdk/tmp/score_agg_daily.gz'
df = pd.read_csv(filename, dtype={'user_id':str, 'work_station':int, 'payment_score':int}, index_col='user_id', nrows=None)
df.shape
# Out:
# (20141178, 13)

# %%
df.head()
# Out:
#                       work_station  payment_score  gender_score  age_score  \
# user_id
# -1000000110326343913             0              0           4.0        2.0
# -1000000144354477425             1              0           4.0        4.9
# -1000001506781019035             0              0           4.0        4.8
# -1000005001834918084             1              0           0.0        0.0
# -1000007235349542945             0              0           0.0        0.0
#
#                       device_score  address_score  travel_score  \
# user_id
# -1000000110326343913           0.0            1.0           0.0
# -1000000144354477425           3.5            5.0           0.0
# -1000001506781019035           3.5            3.5           0.0
# -1000005001834918084           0.0            3.5           0.0
# -1000007235349542945           0.0            0.0           0.0
#
#                       airline_score  luxury_score  resort_score  hotel_score  \
# user_id
# -1000000110326343913            0.0           0.0           0.0          0.0
# -1000000144354477425            0.0           0.0           0.0          0.0
# -1000001506781019035            0.0           0.0           0.0          0.0
# -1000005001834918084            0.0           0.0           0.0          0.0
# -1000007235349542945            0.0           0.0           0.0          0.0
#
#                       tour_score  shopping_score
# user_id
# -1000000110326343913         0.0             0.0
# -1000000144354477425         0.0             0.0
# -1000001506781019035         0.0             3.0
# -1000005001834918084         0.0             0.0
# -1000007235349542945         0.0             0.0

# %%
score_columns = [x for x in df.columns if "score" in x ]

# %%
# gs = gridspec.GridSpec(nrows=4, ncols=2)
# plt.figure(figsize=(30,40))
# for r in range(4):
#     for c in range(2):
#         plt.subplot(gs[r,c])
#         col = column_name[r * 2 + c]
#         sns.distplot(df[col])
#         plt.title(col)

# %%
def get_value_counts(df):
    for col in df.columns:
        print(col, "---------------------")
        print(df[col].value_counts(sort=False).sort_index(ascending=True))

# %% [markdown]
# # Count frequency for each column

# %%
# get_value_counts(df)

# %%
# def filter_agency():

# %%
booking_columns = ['airline_score', 'resort_score', 'hotel_score', 'tour_score']
df['booking'] = (df[booking_columns].sum(axis=1)) > 0
df['total_score'] = df[score_columns].sum(axis=1)
df.head()
# Out:
#                       work_station  payment_score  gender_score  age_score  \
# user_id
# -1000000110326343913             0              0           4.0        2.0
# -1000000144354477425             1              0           4.0        4.9
# -1000001506781019035             0              0           4.0        4.8
# -1000005001834918084             1              0           0.0        0.0
# -1000007235349542945             0              0           0.0        0.0
#
#                       device_score  address_score  travel_score  \
# user_id
# -1000000110326343913           0.0            1.0           0.0
# -1000000144354477425           3.5            5.0           0.0
# -1000001506781019035           3.5            3.5           0.0
# -1000005001834918084           0.0            3.5           0.0
# -1000007235349542945           0.0            0.0           0.0
#
#                       airline_score  luxury_score  resort_score  hotel_score  \
# user_id
# -1000000110326343913            0.0           0.0           0.0          0.0
# -1000000144354477425            0.0           0.0           0.0          0.0
# -1000001506781019035            0.0           0.0           0.0          0.0
# -1000005001834918084            0.0           0.0           0.0          0.0
# -1000007235349542945            0.0           0.0           0.0          0.0
#
#                       tour_score  shopping_score  booking  total_score
# user_id
# -1000000110326343913         0.0             0.0    False          7.0
# -1000000144354477425         0.0             0.0    False         17.4
# -1000001506781019035         0.0             3.0    False         18.8
# -1000005001834918084         0.0             0.0    False          3.5
# -1000007235349542945         0.0             0.0    False          0.0

# %%
condition = ~((df['work_station']) & (df['booking']) & (~df['payment_score']))
condition = condition & (df['total_score'] > 0)

# %%
def get_milestone_income(income_arr):
    LUXURY_SCORE = np.percentile(income_arr, 99.99)
    HIGH_INCOME_SOCRE = np.percentile(income_arr, 94)
    MEDIUM_INCOME_SCORE = np.percentile(income_arr, 58)
    return [MEDIUM_INCOME_SCORE, HIGH_INCOME_SOCRE, LUXURY_SCORE]

# %%
income_milestones = get_milestone_income(df[condition]['total_score'])
print(income_milestones)
# Out:
# [11.8, 18.3, 29.300000000000004]

# %%
def classify_income(x, income_milestones):
    for (i, income) in enumerate(income_milestones):
        if (x < income):
            return i
    return len(income_milestones)

# %%
df['income'] = df['total_score'].apply(lambda x: classify_income(x, income_milestones))
df[~condition]['income'] = 0

# %%
df[df['income'] == 3].shape
# Out:
# (1902, 16)

# %% [markdown]
# # Distribution on total_score
# ### Lots of users with low score <=5

# %%
df[df['total_score'] == 0]
# Out:
#                       work_station  payment_score  gender_score  age_score  \
# user_id
# -1000007235349542945             0              0           0.0        0.0
# -1000015891553737538             0              0           0.0        0.0
# -1000015947525150613             0              0           0.0        0.0
# -1000026235111612650             0              0           0.0        0.0
# -1000029535338957186             0              0           0.0        0.0
# -100004016073296257              0              0           0.0        0.0
# -100004051122793055              0              0           0.0        0.0
# -1000044789468166262             0              0           0.0        0.0
# -1000046339818385719             0              0           0.0        0.0
# -1000054224782010372             0              0           0.0        0.0
# -1000057166955315497             0              0           0.0        0.0
# -1000062178530948683             0              0           0.0        0.0
# -1000064170156777597             0              0           0.0        0.0
# -1000069513148991911             0              0           0.0        0.0
# -100007320558218595              0              0           0.0        0.0
# -1000073475102631438             0              0           0.0        0.0
# -1000083536495244060             0              0           0.0        0.0
# -1000084928979688912             0              0           0.0        0.0
# -1000086785919826424             0              0           0.0        0.0
# -1000098315555190704             0              0           0.0        0.0
# -1000104808100114454             0              0           0.0        0.0
# -1000106812323490944             0              0           0.0        0.0
# -1000115605662073865             0              0           0.0        0.0
# -1000118723307894394             0              0           0.0        0.0
# -1000121009587540662             0              0           0.0        0.0
# -1000127243083570332             0              0           0.0        0.0
# -1000135278675059675             0              0           0.0        0.0
# -1000136494313729412             0              0           0.0        0.0
# -10001374282439762               0              0           0.0        0.0
# -1000152310164521128             0              0           0.0        0.0
# ...                            ...            ...           ...        ...
#  999846313711201954              0              0           0.0        0.0
#  999846970742080344              0              0           0.0        0.0
#  999864324213872286              0              0           0.0        0.0
#  99986556101467413               0              0           0.0        0.0
#  99986592865346770               0              0           0.0        0.0
#  999868999212278037              0              0           0.0        0.0
#  999914538612410110          0.0             0.0    False          0.0
#  99991836206045591           0.0             0.0    False          0.0
#  999924102108302765          0.0             0.0    False          0.0
#  99992805296620256           0.0             0.0    False          0.0
#  999932991906730058          0.0             0.0    False          0.0
#  999940499804843339          0.0             0.0    False          0.0
#  999952575043054150          0.0             0.0    False          0.0
#  999955603517691545          0.0             0.0    False          0.0
#  999956244918145762          0.0             0.0    False          0.0
#  999964476856149134          0.0             0.0    False          0.0
#  999980140226403614          0.0             0.0    False          0.0
#  99998174715935884           0.0             0.0    False          0.0
#  999988486392005870          0.0             0.0    False          0.0
#  999993979505654815          0.0             0.0    False          0.0
#  999994038885603274          0.0             0.0    False          0.0
#  999995335039659318          0.0             0.0    False          0.0
#
# [3275219 rows x 15 columns]

# %%
sns.distplot(df['total_score'])

# %% [markdown]
# # Check value counts for all users with total_score < 5
# - Gender: Unknown
# - Age: Unknown
# - Other Properties: Almost score 0.0

# %%
# get_value_counts(df[df['total_score'] < 5])

# %% [markdown]
# # Check value counts for all users with total_score >= 5

# %%
# get_value_counts(df[df['total_score'] >= 5])

# %% [markdown]
# # Now, check the distribution of users with total_score >=5
#
# ## It skew to the left with a long right tail

# %%
sns.distplot(df[df['total_score'] >= 5]['total_score'], bins=15, hist=True, kde=True)

# %% [markdown]
# # Check value counts for all users with total_score >20
# - Gender: identify
# - Age: 5 score means 26-55 age
# - Other Properties:

# %%
# get_value_counts(df[df['total_score'] > 20])

# %% [markdown]
# # Check users with total score >30

# %%
df[df['total_score'] > 30].sort_values(by=['total_score'], ascending=False)
# Out:
#                       work_station  payment_score  gender_score  age_score  \
# user_id
# -1321516036661715437             0              5           4.0        4.8
#  8586332270159412563             1              5           4.0        4.8
# -3991504323008295359             0              5           5.0        4.8
#  7923963689987561180             1              5           4.0        4.8
# -3991504323008295359             0              5           5.0        4.8
#  6727181745616068235             0              5           5.0        4.8
# -5107955237164203607             0              5           4.0        4.9
# -5107955237164203607             0              5           4.0        4.9
#  5808862419484830084             0              5           5.0        4.8
#  5808862419484830084             0              5           5.0        4.8
#  6932183690755558107             0              5           4.0        4.8
# -7985566765278132715             0              5           4.0        5.0
# -6366250908372403912             0              0           5.0        4.9
# -6366250908372403912             0              0           5.0        4.9
# -7746345272990669394             1              5           4.0        5.0
# -7746345272990669394             1              5           4.0        5.0
# -5032596988049920242             0              5           4.0        4.8
#  5071020160705117407             1              5           5.0        5.0
# -2811332133825881581             1              5           4.0        5.0
# -5183979973818796843             0              5           4.0        2.0
# -8406615047619469355             1              5           5.0        4.9
# -8406615047619469355             1              5           5.0        4.9
#  2924962911861453610             0              5           5.0        4.9
#  8549568638459048910             0              5           5.0        4.8
# -4007705914826464718             0              0           4.0        4.8
# -4007705914826464718             0              0           4.0        4.8
#  8549568638459048910             0              5           5.0        4.8
# -3085826720074775794             0              0           5.0        4.8
# -3085826720074775794             0              0           5.0        4.8
# -2679290088925812460             1              0           4.0        5.0
# ...                            ...            ...           ...        ...
#  4817861526901191940         0.0             3.0     True       30.050       2
# -5111630239972547137         0.0             3.0    False       30.050       2
# -4266696839062621623         0.0             3.0     True       30.050       2
#  3997967748038739379         0.0             3.0    False       30.050       2
# -3506272270239538842         0.0             3.0     True       30.050       2
# -5606226557550534037         0.0             3.0    False       30.050       2
# -7761963933733760659         0.0             3.0    False       30.050       2
# -7761963933733760659         0.0             3.0    False       30.050       2
#  492953542676048167          0.0             3.0     True       30.050       2
# -292714638308543731          0.0             3.0    False       30.050       2
# -6002448946385663525         0.0             3.0    False       30.050       2
# -693151833887468928          0.0             3.0     True       30.050       2
#  5786987229518857246         0.0             3.0     True       30.050       2
#  5786987229518857246         0.0             3.0     True       30.050       2
# -1391685471011408526         0.0             3.0    False       30.050       2
# -693151833887468928          0.0             3.0     True       30.050       2
# -4266696839062621623         0.0             3.0     True       30.050       2
# -5574293151522134289         4.0             0.0     True       30.050       2
# -6956303962233733457         4.0             3.0     True       30.050       2
#  8191666564994060929         0.0             3.0    False       30.050       2
# -4759260758208254245         0.0             3.0    False       30.050       2
# -1391685471011408526         0.0             3.0    False       30.050       2
#  5217663002907014606         0.0             3.0    False       30.050       2
#  5217663002907014606         0.0             3.0    False       30.050       2
# -8209337655256781299         0.0             0.0     True       30.050       2
# -1780787124920374295         0.0             3.0     True       30.050       2
#  4533064104686711735         0.0             3.0     True       30.050       2
#  8191666564994060929         0.0             3.0    False       30.050       2
#  769852881443969753          0.0             0.0     True       30.025       2
#
# [1375 rows x 16 columns]

# %% [markdown]
# ### Percentage of usres who have total_score > 20

# %%
len(df[df['total_score'] > 20]) / len(df) * 100

# %% [markdown]
# ### Percentage of usres who havetotal_score > 15

# %%
len(df[df['total_score'] > 15]) / len(df) * 100

# %% [markdown]
# # Check users with smart phone

# %%
df_smart_phone = df[(df['os_name_score'] == 3) | (df['os_name_score'] == 3.5) | (df['os_name_score'] == 4.5)]

# %%
get_value_counts(df_smart_phone)

# %%
sns.distplot(df_smart_phone[df_smart_phone['total_score'] >= 5]['total_score'], bins=15, hist=True, kde=True)

# %%
print(100.0 * len(df_smart_phone[df_smart_phone['total_score'] > 15]) / len(df_smart_phone[df_smart_phone['total_score'] >=5]))

# %% [markdown]
# # Statistic Test

# %%
x_label_income = ['Low', 'Medium', 'High', 'Luxury']

# %%
income_Bachan = [2532818, 1506937, 259549, 4562]

# %%
# income_Bachan_prop = income_Bachan / np.sum(income_Bachan)
# income_Bachan_prop

# %%
# income_Bachan_accumulate_prop = np.cumsum(income_Bachan_prop)
# print(income_Bachan_accumulate_prop)

# %%
sns.barplot(x=x_label_income, y=income_Bachan)

# %%
df_total_score = df.copy()
df_total_score.head()

# %% [markdown]
# #  Test statistics ( Chi-square statistics on two observed methods)
# - Since the number users on Bachan ~ 5M, our method ~18M, so the test is not correct in my opinion.
# - Perhaps we need to use similar number users for both methods, no need to be the same but not too different

# %%
threshold_income = [9.5, 13, 15.5]

# %%
def get_income_category(x):
    # 0: low, 1: mid, 2: high, 3: so rich (luxury)
    for (i, t) in enumerate(threshold_income):
        if (x < t):
            return i
    return len(threshold_income)

# %%
df_total_score['income'] = df_total_score['total_score'].apply(lambda x: get_income_category(x))

# %%
df_total_score = df_total_score[['total_score', 'income']]
df_total_score.head()

# %%
# income_prop = df_total_score['income'].value_counts(normalize=True, sort=False)
# print(income_prop)
# income_accumulate_prop = np.cumsum(income_prop.values)

# %%
# def get_Kolmogorov_Smirnov_Statistic(first_accumulate_prop, second_accumulate_prob):
#     critical_value = 1.36 * 1 / np.sqrt(len(first_accumulate_prop))
#     gap = abs(first_accumulate_prop - second_accumulate_prob)
#     max_gap = np.max(gap)
#     print('critical value: {} \t Max gap: {}'.format(critical_value, max_gap))
#     return max_gap < critical_value

# %%
# get_Kolmogorov_Smirnov_Statistic(income_Bachan_accumulate_prop, income_accumulate_prop)

# %%
income_our_method = df_total_score['income'].value_counts(sort=False)
income_our_method

# %%
sns.barplot(x=x_label_income, y=income_our_method)
plt.ylabel('Count')

# %%
arr_test = np.array([[11,5,1], [8, 6, 8], [3, 10, 12]])
df_test = pd.DataFrame(index=['ER', 'LR', 'BQ'], columns=['Fruit', 'Flower', 'Mixed'], data=arr_test)

# %%
df_test

# %%
from scipy import stats

# %%
def chi_square_test(df):
    marginal_count_method = df.sum(axis=1)
    marginal_count_income = df.sum(axis=0)
    total_count = marginal_count_method.sum()
    assert total_count == marginal_count_income.sum()
    #print('total count', total_count)
    expected_values = np.zeros_like(df, dtype=float)
    for i in range(expected_values.shape[0]):
        for j in range(expected_values.shape[1]):
            expected_values[i,j] = marginal_count_method[i] * marginal_count_income[j] / total_count
    df_expected = pd.DataFrame(index=df.index, columns=df.columns, data=expected_values)
    print(df_expected)
    chi_square = ((df - df_expected)**2 / df_expected).sum().sum()
    degree_of_freedom = (expected_values.shape[0] - 1 ) * (expected_values.shape[1] - 1)
    print('Chi_square : {} '.format(chi_square))
    print('Degree of freedom : {}'.format(degree_of_freedom))
    p_values = 1 - stats.chi2.cdf(chi_square, degree_of_freedom)
    print('p_value:', p_values)
    return p_values,4

# %%
chi_square_test(df_test)

# %% [markdown]
# ### p_value < 0.05 --> (ER, LR, BQ) and (Fruit, Flower, Mixed) are dependent

# %%
df_two_methods = pd.DataFrame(index=['Bachan', 'Our method'], columns=x_label_income, data=np.array([income_Bachan, income_our_method]))

# %%
df_two_methods

# %%
p_value = chi_square_test(df_two_methods)

# %% [markdown]
# # Check statistics with proportion instead of counting number
# - It is wrong since this statistics test only for the counting number

# %%
income_Bachan_prop = income_Bachan / np.sum(income_Bachan)
income_our_method_prop = df_total_score['income'].value_counts(normalize=True, sort=False).values

# %%
income_Bachan_prop

# %%
income_our_method_prop

# %%
df_two_methods_prop = pd.DataFrame(index=['Bachan', 'Our method'], columns=x_label_income, 
                                   data=np.array([income_Bachan_prop, income_our_method_prop]))

# %%
df_two_methods_prop

# %%
chi_square_test(df_two_methods_prop)
